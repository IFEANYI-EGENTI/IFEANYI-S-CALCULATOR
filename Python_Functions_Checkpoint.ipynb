# %%
# IFEANYI EGENTI
print("IFEANYI'S CALCULATOR")
print()

def calculator(num1, num2):
  operator = input("Please enter an Operator E.g: +, -, *, /: ")
  if operator == "+":
    return num1 + num2
  elif operator == "-":
    return num1 - num2
  elif operator == "*":
    return num1 * num2
  elif operator == "/":
    if num2 == 0:
        return "Error: Cannot divide by zero"
    return num1 / num2
  else:
    return "Invalid Operator. Please use +, -, *, /"


while True:
    try:
      first_number = float(input("Please input your first digit: "))
      second_number = float(input("Please input your second digit: "))
    except ValueError:
        print("Invalid input. Please enter numbers only.")
        continue
    result = calculator(first_number, second_number)
    if isinstance(result, str):
        print(result)
    else:
        print(int(result) if result == int(result) else result)
    print(("Do you want to use Calculator again?"))
    again = input("Input 'yes' to use Calculator again or 'no' to exit: ")
    if again != "yes":
        break
# Out:
# IFEANYI'S CALCULATOR
#
# Please input your first digit: 3.2
# Please input your second digit: 2.6
# Please enter an Operator E.g: +, -, *, /: -
# 0.6000000000000001
# Do you want to use Calculator again?
# Input 'yes' to use Calculator again or 'no' to exit: yes
# Please input your first digit: 22
# Please input your second digit: 0
# Please enter an Operator E.g: +, -, *, /: /
# Error: Cannot divide by zero
# Do you want to use Calculator again?
# Input 'yes' to use Calculator again or 'no' to exit: yes
# Please input your first digit: :
# Invalid input. Please enter numbers only.
# Please input your first digit: a
# Invalid input. Please enter numbers only.
# Please input your first digit: 22
# Please input your second digit: 3
# Please enter an Operator E.g: +, -, *, /: *
# 66
# Do you want to use Calculator again?
# Input 'yes' to use Calculator again or 'no' to exit:
